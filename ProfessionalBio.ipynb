# %% [markdown]
# <a href="https://colab.research.google.com/github/Couper-B/CSC121-30D1/blob/main/ProfessionalBio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assign values to name, goal, Birth_Year, and Current_Year
#Calculate age
#Print the top border line using string multiplication
#Print the bio sentences
#Print the bottom border line using string multiplication

Name = ("Couper")
Goal = ("continue my education at Temple university Japan")
Birth_Year = (2002)
Current_Year = (2026)
Age = str(Current_Year - Birth_Year)

print("="*25)
print("my name is " + Name + " and I am " + Age + " years old. My goal is to " + Goal +".")
print("="*25)
# Out:
# ...
# my name is Couper and I am 24 years old. My goal is to continue my education at Temple university Japan.
# ...
