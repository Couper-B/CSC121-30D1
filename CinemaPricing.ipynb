# %% [markdown]
# <a href="https://colab.research.google.com/github/Couper-B/CSC121-30D1/blob/main/CinemaPricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
# 2. Logic: if age <= 12 or age >= 65, price = 8. otherwise, price = 12
# 3. Logic: if hour <17, subtract 2 from price.
# 4. Print the final price.

age = int(input('How old are you? '))
hour = int(input('When is the movie?(00-23) '))
def calculate_ticket(age,hour):
  # AGE
  if age <= 12 or age >= 65:
    Price = 8
  else:
    Price = 12
  # HOUR
  if hour <17:
    Price = (Price-2)
  print('Your ticket price is:', Price)

calculate_ticket(age,hour)

# PROGRAM LOGIC
# 1. input() for age (int)
# 2. input() for movie hour (int)
# 3. call calculate_ticket()
# Out:
# how old are you? 65
# when is the movie?(00-23) 17
# Your ticket price is: 8
